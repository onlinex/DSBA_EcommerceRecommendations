# %%
import pandas as pd
import numpy as np
import copy
import warnings

warnings.filterwarnings("ignore")

# %%
data = pd.read_parquet('./data/mart/data_mart.parquet')

# %% [markdown]
# <h3>NA</h3>

# %%
data.isna().sum(axis=0).sum()
# Out:
# 0

# %%
df = copy.deepcopy(data)

# %% [markdown]
# <h3>Remove correlation</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.context('seaborn');

# %%
corr = df.corr(method='spearman')

# %%
# flag correlated items as True (except diagonal)
corr_mask = (abs(corr) > 0.85) * np.invert(np.eye(len(corr)).astype(bool))
# remove them
decorr_columns = corr[corr_mask].isna().all()
# get names
decorr_columns = decorr_columns[decorr_columns].index.values

# %%
df = df[decorr_columns]

# %%
corr = df.corr(method='spearman')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_6ec2a_row0_col0,#T_6ec2a_row1_col1,#T_6ec2a_row2_col2,#T_6ec2a_row3_col3,#T_6ec2a_row4_col4,#T_6ec2a_row5_col5,#T_6ec2a_row6_col6,#T_6ec2a_row7_col7,#T_6ec2a_row8_col8,#T_6ec2a_row9_col9,#T_6ec2a_row10_col10,#T_6ec2a_row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_6ec2a_row0_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_6ec2a_row0_col2,#T_6ec2a_row3_col1,#T_6ec2a_row6_col8,#T_6ec2a_row8_col1{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_6ec2a_row0_col3,#T_6ec2a_row10_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_6ec2a_row0_col4{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_6ec2a_row0_col5,#T_6ec2a_row8_col10{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_6ec2a_row0_col6,#T_6ec2a_row7_col3{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_6ec2a_row0_col7,#T_6ec2a_row0_col8,#T_6ec2a_row0_col9,#T_6ec2a_row0_col10,#T_6ec2a_row4_col11,#T_6ec2a_row6_col3,#T_6ec2a_row6_col4,#T_6ec2a_row6_col5,#T_6ec2a_row10_col0,#T_6ec2a_row10_col2,#T_6ec2a_row10_col6,#T_6ec2a_row11_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_6ec2a_row0_col11,#T_6ec2a_row9_col8{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_6ec2a_row1_col0,#T_6ec2a_row7_col4{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_6ec2a_row1_col2,#T_6ec2a_row5_col6,#T_6ec2a_row9_col6{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_6ec2a_row1_col3,#T_6ec2a_row3_col6,#T_6ec2a_row4_col10,#T_6ec2a_row8_col5,#T_6ec2a_row11_col4{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_6ec2a_row1_col4,#T_6ec2a_row8_col9{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_6ec2a_row1_col5{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_6ec2a_row1_col6{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_6ec2a_row1_col7,#T_6ec2a_row2_col1,#T_6ec2a_row2_col11,#T_6ec2a_row3_col7,#T_6ec2a_row4_col7,#T_6ec2a_row5_col8,#T_6ec2a_row7_col11,#T_6ec2a_row9_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_6ec2a_row1_col8,#T_6ec2a_row2_col8,#T_6ec2a_row8_col11,#T_6ec2a_row11_col5{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_6ec2a_row1_col9,#T_6ec2a_row11_col10{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_6ec2a_row1_col10{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_6ec2a_row1_col11,#T_6ec2a_row3_col8{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_6ec2a_row2_col0{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_6ec2a_row2_col3,#T_6ec2a_row4_col3,#T_6ec2a_row8_col3{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_6ec2a_row2_col4,#T_6ec2a_row4_col9{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_6ec2a_row2_col5,#T_6ec2a_row5_col9,#T_6ec2a_row5_col10,#T_6ec2a_row9_col7,#T_6ec2a_row11_col9{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_6ec2a_row2_col6{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_6ec2a_row2_col7,#T_6ec2a_row3_col5{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_6ec2a_row2_col9,#T_6ec2a_row9_col4{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_6ec2a_row2_col10{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_6ec2a_row3_col0{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_6ec2a_row3_col2,#T_6ec2a_row6_col1,#T_6ec2a_row7_col1{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_6ec2a_row3_col4,#T_6ec2a_row10_col3{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_6ec2a_row3_col9{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_6ec2a_row3_col10{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_6ec2a_row3_col11,#T_6ec2a_row4_col8,#T_6ec2a_row5_col2,#T_6ec2a_row5_col3,#T_6ec2a_row8_col2,#T_6ec2a_row8_col7{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_6ec2a_row4_col0{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_6ec2a_row4_col1,#T_6ec2a_row5_col11,#T_6ec2a_row6_col7{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_6ec2a_row4_col2,#T_6ec2a_row4_col6,#T_6ec2a_row5_col1,#T_6ec2a_row9_col1,#T_6ec2a_row10_col5,#T_6ec2a_row11_col2{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_6ec2a_row4_col5,#T_6ec2a_row8_col6{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_6ec2a_row5_col0{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_6ec2a_row5_col4,#T_6ec2a_row7_col10{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_6ec2a_row5_col7,#T_6ec2a_row6_col2,#T_6ec2a_row11_col8{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_6ec2a_row6_col0{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_6ec2a_row6_col9,#T_6ec2a_row9_col0,#T_6ec2a_row10_col8{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_6ec2a_row6_col10,#T_6ec2a_row11_col7{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_6ec2a_row6_col11{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_6ec2a_row7_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_6ec2a_row7_col2{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_6ec2a_row7_col5{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_6ec2a_row7_col6{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_6ec2a_row7_col8{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_6ec2a_row7_col9{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_6ec2a_row8_col0{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_6ec2a_row8_col4{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_6ec2a_row9_col3{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_6ec2a_row9_col5,#T_6ec2a_row10_col4,#T_6ec2a_row11_col3{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_6ec2a_row9_col10{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_6ec2a_row9_col11,#T_6ec2a_row10_col11{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_6ec2a_row10_col7{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_6ec2a_row10_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_6ec2a_row11_col0,#T_6ec2a_row11_col6{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }</style><table id="T_6ec2a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >avg_item_profit</th>        <th class="col_heading level0 col1" >related products</th>        <th class="col_heading level0 col2" >office goods</th>        <th class="col_heading level0 col3" >breastfeeding products</th>        <th class="col_heading level0 col4" >textile, knitwear</th>        <th class="col_heading lev

# %%
df.shape
# Out:
# (67724, 12)

# %% [markdown]
# <h3>Remove outliers</h3>

# %%
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor

# %%
# %%time
outliers = IsolationForest(n_estimators=20, random_state=0).fit_predict(df.values)  # fit 3 trees  
outliers = (outliers+1)//2

print('% of outliers with Isolation forest:', 1 - (np.sum(outliers) / df.shape[0]))
# Out:
# % of outliers with Isolation forest: 0.017763274466954138
# CPU times: user 320 ms, sys: 33.5 ms, total: 354 ms
# Wall time: 353 ms

# %%
df = df.loc[np.array(df.index)[outliers == 1]]

# %%
df.shape
# Out:
# (66521, 12)

# %% [markdown]
# <h3>Normalize data</h3>

# %%
from sklearn import preprocessing

# %%
# define scaler
scaler = preprocessing.StandardScaler()
# normalize
X = scaler.fit_transform(df)

# %% [markdown]
# <h3>K-means</h3>

# %%
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, MeanShift, MiniBatchKMeans, OPTICS

# %%
from scipy.spatial.distance import cdist

# %%
# %%time
# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k, max_iter=500, n_init=20, random_state=7).fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
    
    print('{} / {}'.format(k,K[-1]))
# Out:
# 1 / 9
# 2 / 9
# 3 / 9
# 4 / 9
# 5 / 9
# 6 / 9
# 7 / 9
# 8 / 9
# 9 / 9
# CPU times: user 43.6 s, sys: 10.1 s, total: 53.7 s
# Wall time: 8.35 s

# %%
# Plot the elbow
plt.figure(figsize=(10,6))
plt.axvline(4, 0, 1, label='slope change #1', color='red')
plt.axvline(8, 0, 1, label='slope change #2', color='orange')
plt.plot(K, distortions, 'bx-')
plt.xlabel('k - number of clusters')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.legend(); plt.show()

# %% [markdown]
# <h3>Visualize</h3>

# %%
from sklearn.decomposition import PCA, TruncatedSVD

# %%
Y_pca = PCA(n_components=2).fit_transform(X);
Y_svd = TruncatedSVD(n_components=2).fit_transform(X);

# %%
K = 4
kmeanModel = KMeans(n_clusters=K, max_iter=500, n_init=20, random_state=7).fit(X)

# %%
np.random.seed(21)
colors = np.sqrt(np.random.randint(0,255, size=(K, 3))/255)
c_arr = np.array(list(map(lambda x: colors[x], list(kmeanModel.labels_))))

plt.figure(figsize=(16,5)); plt.title('PCA (K-means)')
plt.scatter(Y_pca[:, 0], Y_pca[:, 1], c=c_arr);

plt.figure(figsize=(16,5)); plt.title('SVD (K-means)')
plt.scatter(Y_svd[:, 0], Y_svd[:, 1], c=c_arr);

# %%
labels, counts = np.unique(kmeanModel.labels_, return_counts=True)

# %%
pd.Series(data=counts, index=labels).sort_values(ascending=False)
# Out:
# 1    31845
# 3    20106
# 2    10594
# 0     3976
# dtype: int64

# %% [markdown]
# <h3>DBSCAN</h3>

# %%
import math

# %%
# %%time
X_sample = pd.DataFrame(X).sample(frac=0.10, random_state=42).values
eps, cluster_counts = [], []
for i in range(0,10):
    eps_p = 1.5 + 0.1*i
    dbscan = DBSCAN(eps=eps_p, algorithm='kd_tree', n_jobs=-1).fit(X_sample)
    n_clusters_ = len(set(dbscan.labels_)) - (1 if -1 in dbscan.labels_ else 0)
    eps.append(eps_p); cluster_counts.append(n_clusters_)
    print('{} / {}'.format(i+1, 9))
# Out:
# 1 / 9
# 2 / 9
# 3 / 9
# 4 / 9
# 5 / 9
# 6 / 9
# 7 / 9
# 8 / 9
# 9 / 9
# 10 / 9
# CPU times: user 47.4 s, sys: 379 ms, total: 47.7 s
# Wall time: 7.99 s

# %%
plt.figure(figsize=(20,5));
plt.yticks(range(min(cluster_counts), math.ceil(max(cluster_counts))+1));
plt.bar(np.round(np.array(eps), 2).astype(str), cluster_counts)
plt.xlabel('eps - Maximum distance between two samples for one to be considered as in the neighborhood of the other.')
plt.ylabel('number of clusters')
plt.title('DBSCAN');

# %% [markdown]
# <h3>T-SNE</h3>

# %%
from sklearn.manifold import TSNE

# %%
x_sample = np.random.choice(len(X), size=10000, replace=False)

# %%
# %%time
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=600)
tsne_results = tsne.fit_transform(X[x_sample])
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.116s...
# [t-SNE] Computed neighbors for 10000 samples in 1.805s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.021547
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.821732
# [t-SNE] KL divergence after 600 iterations: 0.722007
# CPU times: user 3min 51s, sys: 8.99 s, total: 4min
# Wall time: 39.1 s

# %%
sne_labels = kmeanModel.predict(X)[x_sample]

# %%
tSNE = pd.DataFrame(np.vstack((tsne_results.T, sne_labels)).T, columns=['d1', 'd2', 'k'])

plt.figure(figsize=(16,7)); plt.title('t-SNE')
sns.scatterplot(x='d1', y='d2', hue='k', data=tSNE, legend='full', alpha=1.,
                palette=sns.color_palette('hls', kmeanModel.n_clusters));

# %% [markdown]
# <h3>RFM</h3>

# %%
#Recency — number of days since the last purchase
#Frequency — number of transactions made over a given period
#Monetary — amount spent over a given period of time

# %%
ds = pd.read_parquet('./data/clean/all_positions.parquet')

# %%
ds = ds.rename(columns={'Телефон_new': 'phone'})

# %%
ds['ДатаДоставки'] = pd.to_datetime(ds['ДатаДоставки'], format='%m/%d/%Y')

# %%
ds = ds.sort_values(by='ДатаДоставки', ascending=False).groupby('phone').head(1)

# %%
most_recent = ds['ДатаДоставки'].max()

# %%
# Recency
ds['Recency'] = most_recent - ds['ДатаДоставки']

# %%
Recency = ds.set_index('phone')['Recency'].dropna()
Recency = Recency[Recency.index.isin(data.index)]
Recency
# Out:
# phone
# 55575056-49515452494870     0 days
# 55574956-52525654545279     2 days
# 55574948-52525657515579     4 days
# 55575056-50525655495477     6 days
# 55575050-49535356485779     6 days
#                             ...
# 55574954-50545350575374   148 days
# 55574954-52545555485176   148 days
# 55575456-56555452505276   148 days
# 55574953-51575648504878   148 days
# 55575053-48485251514879   148 days
# Name: Recency, Length: 67724, dtype: timedelta64[ns]

# %%
recency = pd.DataFrame(Recency.dt.days)
frequency = data[['successful_orders_count']].rename(columns={'successful_orders_count': 'Frequency'})
monetary = data[['total_profit']].rename(columns={'total_profit': 'Monetary'})

# %%
assert recency.shape == frequency.shape == monetary.shape

# %%
RFM = pd.merge(pd.merge(recency, frequency, on='phone'), monetary, on='phone')

# %%
RFM
# Out:
#                          Recency  Frequency  Monetary
# phone
# 55575056-49515452494870        0          5   2340.60
# 55574956-52525654545279        2          1    175.60
# 55574948-52525657515579        4          2    152.63
# 55575056-50525655495477        6          1   2497.31
# 55575050-49535356485779        6          1     89.91
# ...                          ...        ...       ...
# 55574954-50545350575374      148          1    179.85
# 55574954-52545555485176      148          1    169.00
# 55575456-56555452505276      148          1     71.76
# 55574953-51575648504878      148          1   1441.71
# 55575053-48485251514879      148          1    496.30
#
# [67724 rows x 3 columns]

# %%
# Plot RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(RFM['Recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(RFM['Frequency'][RFM['Frequency'] < RFM['Frequency'].quantile(0.999)])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(RFM['Monetary'][RFM['Monetary'] < RFM['Monetary'].quantile(0.97)])
# Show the plot
plt.show()

# %%
# --Calculate R and F groups--
# Create labels for Recency and Frequency
r_labels = range(4, 0, -1); f_labels = range(1, 4)
# Assign these labels to 4 equal percentile groups 
r_groups = pd.qcut(RFM['Recency'], q=4, labels=r_labels)
# Assign these labels to 4 equal percentile groups 
f_groups = pd.qcut(RFM['Frequency'], q=20, labels=f_labels, duplicates='drop')
# Create new columns R and F 
RFM = RFM.assign(R = r_groups.values, F = f_groups.values)
RFM.head()
# Out:
#                          Recency  Frequency  Monetary  R  F
# phone
# 55575056-49515452494870        0          5   2340.60  4  3
# 55574956-52525654545279        2          1    175.60  4  1
# 55574948-52525657515579        4          2    152.63  4  1
# 55575056-50525655495477        6          1   2497.31  4  1
# 55575050-49535356485779        6          1     89.91  4  1

# %%
# Create labels for MonetaryValue
m_labels = range(1, 5)
# Assign these labels to three equal percentile groups 
m_groups = pd.qcut(RFM['Monetary'], q=4, labels=m_labels)
# Create new column M
RFM = RFM.assign(M = m_groups.values)

# %%
RFM
# Out:
#                          Recency  Frequency  Monetary  R  F  M
# phone
# 55575056-49515452494870        0          5   2340.60  4  3  4
# 55574956-52525654545279        2          1    175.60  4  1  2
# 55574948-52525657515579        4          2    152.63  4  1  2
# 55575056-50525655495477        6          1   2497.31  4  1  4
# 55575050-49535356485779        6          1     89.91  4  1  1
# ...                          ...        ...       ... .. .. ..
# 55574954-50545350575374      148          1    179.85  1  1  2
# 55574954-52545555485176      148          1    169.00  1  1  2
# 55575456-56555452505276      148          1     71.76  1  1  1
# 55574953-51575648504878      148          1   1441.71  1  1  4
# 55575053-48485251514879      148          1    496.30  1  1  3
#
# [67724 rows x 6 columns]

# %%
# %%time
# Concat RFM quartile values to create RFM Segments
def join_rfm(x): 
    return str(int(x['R'])) + str(int(x['F'])) + str(int(x['M']))

RFM['RFM_Segment_Concat'] = RFM.apply(join_rfm, axis=1)
rfm = RFM
rfm.head()
# Out:
# CPU times: user 856 ms, sys: 10.3 ms, total: 866 ms
# Wall time: 872 ms
#                          Recency  Frequency  Monetary  R  F  M  \
# phone
# 55575056-49515452494870        0          5   2340.60  4  3  4
# 55574956-52525654545279        2          1    175.60  4  1  2
# 55574948-52525657515579        4          2    152.63  4  1  2
# 55575056-50525655495477        6          1   2497.31  4  1  4
# 55575050-49535356485779        6          1     89.91  4  1  1
#
#                         RFM_Segment_Concat
# phone
# 55575056-49515452494870                434
# 55574956-52525654545279                412
# 55574948-52525657515579                412
# 55575056-50525655495477                414
# 55575050-49535356485779                411

# %%
# Count num of unique segments
rfm_count_unique = rfm.groupby('RFM_Segment_Concat')['RFM_Segment_Concat'].nunique()
print('Number of unique segmens:', rfm_count_unique.sum())
# Out:
# Number of unique segmens: 48

# %% [markdown]
# <h3>Summing the score</h3>

# %%
# Calculate RFM_Score
rfm['RFM_Score'] = rfm[['R','F','M']].sum(axis=1)
print(rfm['RFM_Score'].head())
# Out:
# phone
# 55575056-49515452494870    11
# 55574956-52525654545279     7
# 55574948-52525657515579     7
# 55575056-50525655495477     9
# 55575050-49535356485779     6
# Name: RFM_Score, dtype: int64

# %%
# Define rfm_level function
def rfm_level(df):
    if df['RFM_Score'] >= 9:
        return 'Can\'t Loose Them'
    elif ((df['RFM_Score'] >= 8) and (df['RFM_Score'] < 9)):
        return 'Champions'
    elif ((df['RFM_Score'] >= 7) and (df['RFM_Score'] < 8)):
        return 'Loyal'
    elif ((df['RFM_Score'] >= 6) and (df['RFM_Score'] < 7)):
        return 'Potential'
    elif ((df['RFM_Score'] >= 5) and (df['RFM_Score'] < 6)):
        return 'Sleeping' # Primising
    elif ((df['RFM_Score'] >= 4) and (df['RFM_Score'] < 5)):
        return 'Needs Attention'
    else:
        return 'Require Activation'
# Create a new variable RFM_Level
rfm['RFM_Level'] = rfm.apply(rfm_level, axis=1)
# Print the header with top 5 rows to the console
rfm.head()
# Out:
#                          Recency  Frequency  Monetary  R  F  M  \
# phone
# 55575056-49515452494870        0          5   2340.60  4  3  4
# 55574956-52525654545279        2          1    175.60  4  1  2
# 55574948-52525657515579        4          2    152.63  4  1  2
# 55575056-50525655495477        6          1   2497.31  4  1  4
# 55575050-49535356485779        6          1     89.91  4  1  1
#
#                         RFM_Segment_Concat  RFM_Score         RFM_Level
# phone
# 55575056-49515452494870                434         11  Can't Loose Them
# 55574956-52525654545279                412          7             Loyal
# 55574948-52525657515579                412          7             Loyal
# 55575056-50525655495477                414          9  Can't Loose Them
# 55575050-49535356485779                411          6         Potential

# %% [markdown]
# <h3>RFM results</h3>

# %%
import squarify

# %%
# Calculate average values for each RFM_Level, and return a size of each segment 
rfm_level_agg = rfm.groupby('RFM_Level').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': ['mean', 'count']
}).round(1)
# Print the aggregated dataset
print(rfm_level_agg)
# Out:
#                    Recency Frequency Monetary
#                       mean      mean     mean  count
# RFM_Level
# Can't Loose Them      33.9       3.0   1934.5   7653
# Champions             42.7       1.6   1120.4   7817
# Loyal                 54.3       1.3    758.4  11228
# Needs Attention      102.5       1.1     11.0   9359
# Potential             68.7       1.2    495.2  15297
# Require Activation   120.1       1.0   -137.7   4289
# Sleeping              86.4       1.1    182.2  12081

# %%
rfm_level_agg.columns = rfm_level_agg.columns.droplevel()
rfm_level_agg.columns = ['RecencyMean','FrequencyMean','MonetaryMean', 'Count']
#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 9)
squarify.plot(sizes=rfm_level_agg['Count'], 
              label=['Can\'t Loose Them',
                     'Champions',
                     'Loyal',
                     'Needs Attention',
                     'Potential', 
                     'Sleeping', 
                     'Require Activation'],
              color=['#e63946',
                     '#e76f51',
                     '#f1faee',
                     '#a8dadc',
                     '#457b9d',
                     '#1d3557',
                     '#14213d'],
              alpha=.6,)
plt.title("RFM Segments",fontsize=18,fontweight="bold")
plt.axis('off')
plt.show()

# %% [markdown]
# <h3>Save RFM</h3>

# %%
from pathlib import Path

# %%
Path("./data/rfm").mkdir(parents=True, exist_ok=True)

# %%
rfm.to_parquet('./data/rfm/scores.parquet')
